# %%
import sys

import pandas as pd
import numpy as np
from pathlib import Path

# %%
SPLITS = ["train", "val", "test"]
SIZE = 2
SOURCE = Path("/mnt/jbrockma/bachelor-thesis/data/oct/OCT")

# %%
split_info = pd.read_csv("/mnt/jbrockma/bachelor-thesis/medmnist_data_split/octmnist_split_info.csv", index_col="image_id")
split_info
# Out:
#                    split  index
# image_id
# CNV-732516-77      train      0
# NORMAL-3476775-5   train      1
# NORMAL-1725461-13  train      2
# NORMAL-5103899-4   train      3
# CNV-7604641-38     train      4
# ...                  ...    ...
# DRUSEN-8350131-2    test    995
# DME-859014-1        test    996
# NORMAL-3063933-2    test    997
# DME-943690-6        test    998
# CNV-818474-4        test    999
#
# [109309 rows x 2 columns]

# %%
split_value_counts = split_info["split"].value_counts()

n_samples_of_split = {SPLIT: split_value_counts[SPLIT] for SPLIT in SPLITS}

# Prepare numpy arrays
images_of_split = {}
for SPLIT in SPLITS:
    n_samples = n_samples_of_split[SPLIT]
    images_of_split[SPLIT] = np.empty((n_samples, SIZE, SIZE), dtype=np.uint8)

# %%
info_of_image = {im_id: (split, idx) for im_id, split, idx in split_info.itertuples()}
info_of_image
# Out:
# {'CNV-732516-77': ('train', 0),
#  'NORMAL-3476775-5': ('train', 1),
#  'NORMAL-1725461-13': ('train', 2),
#  'NORMAL-5103899-4': ('train', 3),
#  'CNV-7604641-38': ('train', 4),
#  'NORMAL-7081085-9': ('train', 5),
#  'DME-1591159-85': ('train', 6),
#  'CNV-3318854-209': ('train', 7),
#  'NORMAL-4419154-8': ('train', 8),
#  'NORMAL-907824-2': ('train', 9),
#  'NORMAL-4556266-2': ('train', 10),
#  'DRUSEN-4934663-36': ('train', 11),
#  'CNV-172472-321': ('train', 12),
#  'CNV-4219137-86': ('train', 13),
#  'DRUSEN-7756213-4': ('train', 14),
#  'CNV-6566667-25': ('train', 15),
#  'CNV-9005459-75': ('train', 16),
#  'NORMAL-9267111-53': ('train', 17),
#  'CNV-2760476-3': ('train', 18),
#  'CNV-6215140-26': ('train', 19),
#  'CNV-6668596-145': ('train', 20),
#  'NORMAL-5810801-1': ('train', 21),
#  'NORMAL-6830356-3': ('train', 22),
#  'CNV-1188386-762': ('train', 23),
#  'NORMAL-3912695-7': ('train', 24),
#  'CNV-4974377-25': ('train', 25),
#  'NORMAL-4670940-2': ('train', 26),
#  'NORMAL-7835584-9': ('train', 27),
#  'NORMAL-5783190-8': ('train', 28),
#  'CNV-5603164-55': ('train', 29),
#  'NORMAL-2246641-28': ('train', 30),
#  'CNV-1390155-62': ('train', 31),
#  'DME-5313093-17': ('train', 32),
#  'CNV-6001487-2': ('train', 33),
#  'CNV-4921376-122': ('train', 34),
#  'NORMAL-3344565-29': ('train', 35),
#  'NORMAL-1315574-8': ('train', 36),
#  'DME-6716735-29': ('train', 37),
#  'CNV-4974377-40': ('train', 38),
#  'NORMAL-2515109-18': ('train', 39),
#  'DME-866257-4': ('train', 40),
#  'NORMAL-5765166-5': ('train', 41),
#  'NORMAL-6569286-1': ('train', 42),
#  'CNV-9174718-16': ('train', 43),
#  'NORMAL-3161833-6': ('train', 44),
#  'NORMAL-3712655-10': ('train', 45),
#  'CNV-8728968-38': ('train', 46),
#  'NORMAL-5751927-9': ('train', 47),
#  'NORMAL-9259580-6': ('train', 48),
#  'NORMAL-3901239-7': ('train', 49),
#  'CNV-451136-317': ('train', 50),
#  'NORMAL-1953845-6': ('train', 51),
#  'NORMAL-8469406-25': ('train', 52),
#  'NORMAL-4720784-10': ('train', 53),
#  'NORMAL-6503441-33': ('train', 54),
#  'NORMAL-6129007-5': ('train', 55),
#  'CNV-3080163-67': ('train', 56),
#  'CNV-732516-97': ('train', 57),
#  'NORMAL-5952782-10': ('train', 58),
#  'NORMAL-2026176-11': ('train', 59),
#  'NORMAL-9505686-10': ('train', 60),
#  'CNV-6626487-13': ('train', 61),
#  'CNV-3318854-185': ('train', 62),
#  'NORMAL-9020110-8': ('train', 63),
#  'NORMAL-7934335-28': ('train', 64),
#  'NORMAL-3886612-16': ('train', 65),
#  'NORMAL-8667223-11': ('train', 66),
#  'DRUSEN-3571629-5': ('train', 67),
#  'NORMAL-4150703-3': ('train', 68),
#  'NORMAL-15307-4': ('train', 69),
#  'DME-4884451-14': ('train', 70),
#  'DME-8560276-14': ('train', 71),
#  'DME-5086150-5': ('train', 72),
#  'CNV-4951152-34': ('train', 73),
#  'NORMAL-6266427-1': ('train', 74),
#  'DRUSEN-6225622-1': ('train', 75),
#  'NORMAL-9103640-34': ('train', 76),
#  'NORMAL-2275240-12': ('train', 77),
#  'CNV-7710023-169': ('train', 78),
#  'NORMAL-12494-22': ('train', 79),
#  'NORMAL-9591773-5': ('train', 80),
#  'DME-773094-15': ('train', 81),
#  'NORMAL-9729147-13': ('train', 82),
#  'NORMAL-478864-2': ('train', 83),
#  'NORMAL-1235580-5': ('train', 84),
#  'CNV-3200277-12': ('train', 85),
#  'NORMAL-9474396-5': ('train', 86),
#  'NORMAL-5571744-34': ('train', 87),
#  'DRUSEN-7572931-4': ('train', 88),
#  'NORMAL-3136915-11': ('train', 89),
#  'DME-1635931-9': ('train', 90),
#  'NORMAL-8111718-22': ('train', 91),
#  'CNV-1779025-18': ('train', 92),
#  'NORMAL-7585414-11': ('train', 93),
#  'CNV-1784116-5': ('train', 94),
#  'NORMAL-1444350-6': ('train', 95),
#  'NORMAL-6002699-11': ('train', 96),
#  'CNV-1997439-114': ('train', 97),
#  'CNV-2655276-36': ('train', 98),
#  'CNV-698872-14': ('train', 99),
#  'NORMAL-6018588-3': ('train', 100),
#  'NORMAL-2434258-5': ('train', 101),
#  'NORMAL-9393174-12': ('train', 102),
#  'NORMAL-4268267-7': ('train', 103),
#  'NORMAL-1561716-3': ('train', 104),
#  'DME-8560276-20': ('train', 105),
#  'NORMAL-2354163-3': ('train', 106),
#  'CNV-3084376-7': ('train', 107),
#  'CNV-8598714-200': ('train', 108),
#  'NORMAL-1498414-4': ('train', 109),
#  'DRUSEN-6625388-5': ('train', 110),
#  'NORMAL-8605472-7': ('train', 111),
#  'CNV-997190-10': ('train', 112),
#  'CNV-1169820-66': ('train', 113),
#  'DME-4242335-150': ('train', 114),
#  'CNV-7710023-217': ('train', 115),
#  'NORMAL-5375064-8': ('train', 116),
#  'NORMAL-258763-10': ('train', 117),
#  'DME-7750274-6': ('train', 118),
#  'DME-8989419-5': ('train', 119),
#  'NORMAL-5808538-20': ('train', 120),
#  'CNV-8972369-90': ('train', 121),
#  'DME-8770531-35': ('train', 122),
#  'NORMAL-9259580-15': ('train', 123),
#  'CNV-8800510-3': ('train', 124),
#  'CNV-5054419-18': ('train', 125),
#  'DME-8681418-13': ('train', 126),
#  'CNV-6795779-69': ('train', 127),
#  'CNV-4283050-23': ('train', 128),
#  'CNV-6566667-163': ('train', 129),
#  'DRUSEN-1514075-25': ('train', 130),
#  'CNV-1963682-99': ('train', 131),
#  'NORMAL-9503906-1': ('train', 132),
#  'NORMAL-3072988-8': ('train', 133),
#  'NORMAL-4332329-12': ('train', 134),
#  'CNV-6717547-12': ('train', 135),
#  'CNV-564246-2': ('train', 136),
#  'DRUSEN-9540117-37': ('train', 137),
#  'DME-5225805-26': ('train', 138),
#  'CNV-3453634-27': ('train', 139),
#  'NORMAL-3487196-31': ('train', 140),
#  'CNV-8783825-124': ('train', 141),
#  'CNV-7675318-20': ('train', 142),
#  'CNV-732516-188': ('train', 143),
#  'DME-9588051-2': ('train', 144),
#  'NORMAL-8915019-3': ('train', 145),
#  'CNV-6933604-10': ('train', 146),
#  'NORMAL-2700669-2': ('train', 147),
#  'CNV-8086850-25': ('train', 148),
#  'CNV-1997714-2': ('train', 149),
#  'NORMAL-6219392-7': ('train', 150),
#  'CNV-933576-147': ('train', 151),
#  'DME-633268-28': ('train', 152),
#  'DRUSEN-9624303-29': ('train', 153),
#  'CNV-3453634-116': ('train', 154),
#  'DME-8525575-159': ('train', 155),
#  'CNV-4534097-5': ('train', 156),
#  'DME-1888479-44': ('train', 157),
#  'DME-4792882-12': ('train', 158),
#  'DRUSEN-3439251-47': ('train', 159),
#  'NORMAL-3263163-3': ('train', 160),
#  'NORMAL-6696156-47': ('train', 161),
#  'CNV-7694510-4': ('train', 162),
#  'NORMAL-3344565-4': ('train', 163),
#  'CNV-6369482-69': ('train', 164),
#  'NORMAL-3354044-1': ('train', 165),
#  'CNV-1390155-40': ('train', 166),
#  'CNV-4095287-22': ('train', 167),
#  'CNV-3715091-111': ('train', 168),
#  'DME-7763916-105': ('train', 169),
#  'CNV-4952759-265': ('train', 170),
#  'NORMAL-7215804-12': ('train', 171),
#  'NORMAL-5515025-1': ('train', 172),
#  'NORMAL-2510256-21': ('train', 173),
#  'NORMAL-608319-8': ('train', 174),
#  'NORMAL-8959810-5': ('train', 175),
#  'NORMAL-5808538-6': ('train', 176),
#  'NORMAL-4934663-5': ('train', 177),
#  'CNV-5904584-132': ('train', 178),
#  'CNV-6666538-194': ('train', 179),
#  'NORMAL-881747-11': ('train', 180),
#  'CNV-4219137-72': ('train', 181),
#  'NORMAL-745863-2': ('train', 182),
#  'NORMAL-4176900-12': ('train', 183),
#  'DRUSEN-8086850-104': ('train', 184),
#  'NORMAL-9557298-20': ('train', 185),
#  'CNV-4095287-16': ('train', 186),
#  'CNV-9320911-203': ('train', 187),
#  'CNV-9997680-226': ('train', 188),
#  'NORMAL-2757876-14': ('train', 189),
#  'NORMAL-8523253-8': ('train', 190),
#  'CNV-1632795-41': ('train', 191),
#  'CNV-6666538-51': ('train', 192),
#  'NORMAL-3066328-5': ('train', 193),
#  'NORMAL-1252774-6': ('train', 194),
#  'NORMAL-6426359-1': ('train', 195),
#  'CNV-6668596-159': ('train', 196),
#  'NORMAL-3494871-2': ('train', 197),
#  'NORMAL-2541717-20': ('train', 198),
#  'NORMAL-8897341-46': ('train', 199),
#  'DRUSEN-2253582-15': ('train', 200),
#  'NORMAL-872609-29': ('train', 201),
#  'CNV-482704-6': ('train', 202),
#  'NORMAL-6127613-7': ('train', 203),
#  'NORMAL-5345733-19': ('train', 204),
#  'CNV-2116022-71': ('train', 205),
#  'NORMAL-1403854-5': ('train', 206),
#  'NORMAL-9893175-5': ('train', 207),
#  'NORMAL-9294952-15': ('train', 208),
#  'CNV-697731-28': ('train', 209),
#  'CNV-2034494-71': ('train', 210),
#  'CNV-3574650-8': ('train', 211),
#  'CNV-3818682-87': ('train', 212),
#  'NORMAL-9152820-4': ('train', 213),
#  'NORMAL-8258450-7': ('train', 214),
#  'NORMAL-7325223-46': ('train', 215),
#  'NORMAL-6145849-5': ('train', 216),
#  'DME-7846574-2': ('train', 217),
#  'NORMAL-7674707-3': ('train', 218),
#  'CNV-7683197-15': ('train', 219),
#  'NORMAL-4198834-4': ('train', 220),
#  'NORMAL-7105694-24': ('train', 221),
#  'DME-4616882-5': ('train', 222),
#  'NORMAL-7300004-2': ('train', 223),
#  'NORMAL-6524370-2': ('train', 224),
#  'NORMAL-5030676-25': ('train', 225),
#  'CNV-9547888-10': ('train', 226),
#  'NORMAL-906167-5': ('train', 227),
#  'NORMAL-1384-4': ('train', 228),
#  'DRUSEN-8747569-9': ('train', 229),
#  'CNV-9642260-275': ('train', 230),
#  'CNV-1188386-26': ('train', 231),
#  'CNV-4732594-36': ('train', 232),
#  'NORMAL-8487067-14': ('train', 233),
#  'NORMAL-3058252-8': ('train', 234),
#  'NORMAL-7972888-9': ('train', 235),
#  'NORMAL-5027137-6': ('train', 236),
#  'NORMAL-7674707-9': ('train', 237),
#  'DRUSEN-8316281-11': ('train', 238),
#  'DME-3157783-5': ('train', 239),
#  'CNV-8184974-41': ('train', 240),
#  'CNV-2034494-82': ('train', 241),
#  'NORMAL-3921760-6': ('train', 242),
#  'DRUSEN-8213975-1': ('train', 243),
#  'CNV-9374492-313': ('train', 244),
#  'NORMAL-8960652-5': ('train', 245),
#  'NORMAL-1047578-7': ('train', 246),
#  'NORMAL-7725686-3': ('train', 247),
#  'CNV-9374492-273': ('train', 248),
#  'NORMAL-4272704-7': ('train', 249),
#  'CNV-7555604-111': ('train', 250),
#  'CNV-1894770-124': ('train', 251),
#  'CNV-1779025-25': ('train', 252),
#  'NORMAL-6915555-43': ('train', 253),
#  'NORMAL-3420635-2': ('train', 254),
#  'NORMAL-5714726-23': ('train', 255),
#  'CNV-172472-132': ('train', 256),
#  'CNV-172472-171': ('train', 257),
#  'CNV-3413998-5': ('train', 258),
#  'NORMAL-7197896-13': ('train', 259),
#  'DME-4868278-3': ('train', 260),
#  'CNV-8796318-82': ('train', 261),
#  'NORMAL-2339158-17': ('train', 262),
#  'CNV-8982961-33': ('train', 263),
#  'CNV-6581164-135': ('train', 264),
#  'CNV-2515109-8': ('train', 265),
#  'NORMAL-3898646-18': ('train', 266),
#  'CNV-6652117-89': ('train', 267),
#  'CNV-4439963-19': ('train', 268),
#  'NORMAL-6326137-9': ('train', 269),
#  'NORMAL-3261735-2': ('train', 270),
#  'NORMAL-3757443-55': ('train', 271),
#  'DME-6798210-38': ('train', 272),
#  'CNV-1651625-49': ('train', 273),
#  'NORMAL-6704613-6': ('train', 274),
#  'CNV-7732521-120': ('train', 275),
#  'CNV-3200277-11': ('train', 276),
#  'NORMAL-6369482-6': ('train', 277),
#  'NORMAL-9216703-10': ('train', 278),
#  'CNV-4176900-3': ('train', 279),
#  'NORMAL-8153213-2': ('train', 280),
#  'NORMAL-9557298-21': ('train', 281),
#  'DRUSEN-2437193-24': ('train', 282),
#  'NORMAL-2410223-16': ('train', 283),
#  'CNV-3847391-60': ('train', 284),
#  'DME-4242335-83': ('train', 285),
#  'CNV-9374492-441': ('train', 286),
#  'CNV-7159021-20': ('train', 287),
#  'DME-4882651-3': ('train', 288),
#  'NORMAL-4325652-25': ('train', 289),
#  'NORMAL-4041148-3': ('train', 290),
#  'CNV-5409617-85': ('train', 291),
#  'NORMAL-7319607-30': ('train', 292),
#  'NORMAL-3361560-19': ('train', 293),
#  'NORMAL-3473531-12': ('train', 294),
#  'NORMAL-7138480-1': ('train', 295),
#  'NORMAL-6530663-3': ('train', 296),
#  'CNV-4952759-170': ('train', 297),
#  'CNV-6666538-361': ('train', 298),
#  'NORMAL-9240050-9': ('train', 299),
#  'DRUSEN-6193297-7': ('train', 300),
#  'NORMAL-3108219-5': ('train', 301),
#  'NORMAL-9852056-15': ('train', 302),
#  'CNV-6668596-120': ('train', 303),
#  'NORMAL-5543644-4': ('train', 304),
#  'NORMAL-1610264-5': ('train', 305),
#  'NORMAL-6683429-2': ('train', 306),
#  'CNV-3318854-24': ('train', 307),
#  'NORMAL-3358004-1': ('train', 308),
#  'NORMAL-3939799-3': ('train', 309),
#  'NORMAL-7984958-2': ('train', 310),
#  'NORMAL-8855944-10': ('train', 311),
#  'NORMAL-9301250-5': ('train', 312),
#  'NORMAL-8120352-15': ('train', 313),
#  'NORMAL-5689330-7': ('train', 314),
#  'CNV-1729810-19': ('train', 315),
#  'NORMAL-3784423-3': ('train', 316),
#  'NORMAL-9944275-3': ('train', 317),
#  'NORMAL-469935-26': ('train', 318),
#  'NORMAL-6529569-5': ('train', 319),
#  'NORMAL-8970825-4': ('train', 320),
#  'NORMAL-8907654-1': ('train', 321),
#  'NORMAL-9334909-10': ('train', 322),
#  'DME-30521-180': ('train', 323),
#  'NORMAL-9763364-9': ('train', 324),
#  'DRUSEN-8086850-143': ('train', 325),
#  'NORMAL-9627503-3': ('train', 326),
#  'NORMAL-6098724-8': ('train', 327),
#  'CNV-7902439-27': ('train', 328),
#  'CNV-9997680-244': ('train', 329),
#  'NORMAL-495863-11': ('train', 330),
#  'DME-4244491-6': ('train', 331),
#  'DME-5014129-10': ('train', 332),
#  'DME-4643364-1': ('train', 333),
#  'NORMAL-7041041-4': ('train', 334),
#  'NORMAL-1908313-14': ('train', 335),
#  'CNV-7048665-36': ('train', 336),
#  'CNV-2034494-34': ('train', 337),
#  'DME-119840-12': ('train', 338),
#  'NORMAL-3507119-2': ('train', 339),
#  'NORMAL-3664385-51': ('train', 340),
#  'DME-4658666-71': ('train', 341),
#  'CNV-3616460-95': ('train', 342),
#  'NORMAL-8824396-9': ('train', 343),
#  'DRUSEN-2443350-2': ('train', 344),
#  'CNV-7852568-24': ('train', 345),
#  'NORMAL-1348085-18': ('train', 346),
#  'NORMAL-8015555-12': ('train', 347),
#  'CNV-9374492-409': ('train', 348),
#  'CNV-6652117-211': ('train', 349),
#  'DME-9867791-3': ('train', 350),
#  'DME-916226-4': ('train', 351),
#  'CNV-2128644-89': ('train', 352),
#  'CNV-7873827-92': ('train', 353),
#  'CNV-7732521-86': ('train', 354),
#  'CNV-4921376-59': ('train', 355),
#  'CNV-904464-141': ('train', 356),
#  'CNV-7732521-58': ('train', 357),
#  'CNV-8783825-119': ('train', 358),
#  'CNV-1112835-380': ('train', 359),
#  'CNV-8039905-20': ('train', 360),
#  'DRUSEN-328435-1': ('train', 361),
#  'CNV-8728968-12': ('train', 362),
#  'CNV-1390155-1': ('train', 363),
#  'NORMAL-3590718-2': ('train', 364),
#  'NORMAL-7304368-20': ('train', 365),
#  'DME-778975-22': ('train', 366),
#  'CNV-904464-207': ('train', 367),
#  'CNV-4884091-45': ('train', 368),
#  'NORMAL-5714726-17': ('train', 369),
#  'CNV-5689330-15': ('train', 370),
#  'NORMAL-8500412-5': ('train', 371),
#  'NORMAL-7132018-8': ('train', 372),
#  'CNV-8728968-218': ('train', 373),
#  'NORMAL-7829919-6': ('train', 374),
#  'DRUSEN-8316281-1': ('train', 375),
#  'NORMAL-1324027-46': ('train', 376),
#  'CNV-4439963-8': ('train', 377),
#  'NORMAL-7614088-30': ('train', 378),
#  'CNV-9206635-27': ('train', 379),
#  'DME-8371885-18': ('train', 380),
#  'CNV-1305450-153': ('train', 381),
#  'DME-778975-8': ('train', 382),
#  'NORMAL-785813-7': ('train', 383),
#  'DME-8266663-3': ('train', 384),
#  'NORMAL-469935-19': ('train', 385),
#  'DRUSEN-2541184-39': ('train', 386),
#  'NORMAL-8747676-8': ('train', 387),
#  'NORMAL-5565408-8': ('train', 388),
#  'NORMAL-3099713-7': ('train', 389),
#  'NORMAL-9103640-6': ('train', 390),
#  'NORMAL-9416877-4': ('train', 391),
#  'CNV-5429703-67': ('train', 392),
#  'DME-7578162-7': ('train', 393),
#  'DME-2232211-12': ('train', 394),
#  'CNV-6215140-228': ('train', 395),
#  'DME-9721607-91': ('train', 396),
#  'NORMAL-7696092-4': ('train', 397),
#  'CNV-4921376-10': ('train', 398),
#  'NORMAL-5651393-5': ('train', 399),
#  'CNV-6851127-8': ('train', 400),
#  'CNV-137351-145': ('train', 401),
#  'DME-1760955-3': ('train', 402),
#  'CNV-4691762-83': ('train', 403),
#  'NORMAL-5523023-4': ('train', 404),
#  'NORMAL-4030787-11': ('train', 405),
#  'CNV-7873827-25': ('train', 406),
#  'DME-5223925-18': ('train', 407),
#  'CNV-6493580-128': ('train', 408),
#  'DME-3606968-31': ('train', 409),
#  'CNV-7159021-193': ('train', 410),
#  'CNV-7997521-12': ('train', 411),
#  'DRUSEN-2233489-10': ('train', 412),
#  'NORMAL-8115192-3': ('train', 413),
#  'NORMAL-442772-2': ('train', 414),
#  'CNV-4952759-173': ('train', 415),
#  'DRUSEN-8345703-5': ('train', 416),
#  'CNV-692554-17': ('train', 417),
#  'DRUSEN-7184590-11': ('train', 418),
#  'CNV-6170739-9': ('train', 419),
#  'CNV-9005459-39': ('train', 420),
#  'NORMAL-4389726-5': ('train', 421),
#  'NORMAL-4510129-16': ('train', 422),
#  'NORMAL-4111396-18': ('train', 423),
#  'CNV-7907754-71': ('train', 424),
#  'NORMAL-9217961-13': ('train', 425),
#  'DRUSEN-9734808-51': ('train', 426),
#  'NORMAL-6083172-4': ('train', 427),
#  'DME-3064922-57': ('train', 428),
#  'CNV-451136-6': ('train', 429),
#  'NORMAL-3120525-3': ('train', 430),
#  'CNV-9997680-155': ('train', 431),
#  'NORMAL-5246808-6': ('train', 432),
#  'NORMAL-2757876-1': ('train', 433),
#  'NORMAL-3389431-6': ('train', 434),
#  'NORMAL-6409089-28': ('train', 435),
#  'NORMAL-9126051-4': ('train', 436),
#  'DME-5656004-13': ('train', 437),
#  'DME-4787838-1': ('train', 438),
#  'NORMAL-7863843-8': ('train', 439),
#  'NORMAL-2960588-4': ('train', 440),
#  'NORMAL-138971-2': ('train', 441),
#  'NORMAL-2937234-4': ('train', 442),
#  'NORMAL-2204034-6': ('train', 443),
#  'NORMAL-2354163-17': ('train', 444),
#  'NORMAL-1219253-41': ('train', 445),
#  'CNV-2192440-72': ('train', 446),
#  'CNV-3307363-15': ('train', 447),
#  'NORMAL-7076479-20': ('train', 448),
#  'CNV-1290410-121': ('train', 449),
#  'CNV-8656509-17': ('train', 450),
#  'NORMAL-3206854-6': ('train', 451),
#  'CNV-2141150-1': ('train', 452),
#  'NORMAL-7570194-15': ('train', 453),
#  'DME-8019418-44': ('train', 454),
#  'NORMAL-7580720-12': ('train', 455),
#  'CNV-460403-151': ('train', 456),
#  'CNV-954024-14': ('train', 457),
#  'NORMAL-6677177-13': ('train', 458),
#  'CNV-9320911-66': ('train', 459),
#  'NORMAL-2559411-7': ('train', 460),
#  'NORMAL-1577192-10': ('train', 461),
#  'NORMAL-4002313-4': ('train', 462),
#  'CNV-6581164-160': ('train', 463),
#  'NORMAL-828547-32': ('train', 464),
#  'NORMAL-8306156-6': ('train', 465),
#  'NORMAL-9251-6': ('train', 466),
#  'CNV-8184974-77': ('train', 467),
#  'NORMAL-8472707-45': ('train', 468),
#  'NORMAL-1649492-38': ('train', 469),
#  'CNV-6053140-26': ('train', 470),
#  'CNV-137351-52': ('train', 471),
#  'NORMAL-8871445-43': ('train', 472),
#  'CNV-4952759-32': ('train', 473),
#  'CNV-4952759-10': ('train', 474),
#  'NORMAL-4527789-9': ('train', 475),
#  'CNV-2141150-52': ('train', 476),
#  'DME-8889771-84': ('train', 477),
#  'CNV-6493580-78': ('train', 478),
#  'DME-3757443-64': ('train', 479),
#  'NORMAL-5853049-13': ('train', 480),
#  'NORMAL-1614397-13': ('train', 481),
#  'DRUSEN-462675-1': ('train', 482),
#  'DME-3157783-80': ('train', 483),
#  'CNV-1136126-5': ('train', 484),
#  'NORMAL-6979734-10': ('train', 485),
#  'NORMAL-1583447-42': ('train', 486),
#  'CNV-6947782-33': ('train', 487),
#  'NORMAL-9621711-5': ('train', 488),
#  'DME-6704343-18': ('train', 489),
#  'DME-4242335-223': ('train', 490),
#  'DME-30521-209': ('train', 491),
#  'NORMAL-3488701-28': ('train', 492),
#  'NORMAL-1753482-6': ('train', 493),
#  'DRUSEN-7137161-5': ('train', 494),
#  'CNV-7732521-119': ('train', 495),
#  'CNV-9431642-1': ('train', 496),
#  'NORMAL-2475325-6': ('train', 497),
#  'DRUSEN-907869-8': ('train', 498),
#  'CNV-9373856-114': ('train', 499),
#  'DME-7757895-6': ('train', 500),
#  'NORMAL-3258939-18': ('train', 501),
#  'NORMAL-3513192-8': ('train', 502),
#  'DRUSEN-6190971-68': ('train', 503),
#  'NORMAL-6323199-4': ('train', 504),
#  'NORMAL-1312425-16': ('train', 505),
#  'DME-3441556-99': ('train', 506),
#  'NORMAL-1933996-4': ('train', 507),
#  'CNV-3118383-40': ('train', 508),
#  'NORMAL-2973935-7': ('train', 509),
#  'DME-6851127-8': ('train', 510),
#  'DME-9915316-122': ('train', 511),
#  'NORMAL-6170409-5': ('train', 512),
#  'DRUSEN-525301-6': ('train', 513),
#  'CNV-9343663-100': ('train', 514),
#  'CNV-6170739-7': ('train', 515),
#  'NORMAL-8444023-6': ('train', 516),
#  'CNV-9598696-148': ('train', 517),
#  'NORMAL-2349885-8': ('train', 518),
#  'NORMAL-1847888-5': ('train', 519),
#  'CNV-2097858-6': ('train', 520),
#  'NORMAL-803699-1': ('train', 521),
#  'NORMAL-4343117-19': ('train', 522),
#  'NORMAL-6383847-3': ('train', 523),
#  'DME-3441556-46': ('train', 524),
#  'DME-7846574-32': ('train', 525),
#  'DME-8889771-93': ('train', 526),
#  'NORMAL-8970381-1': ('train', 527),
#  'NORMAL-6741932-9': ('train', 528),
#  'NORMAL-3799821-14': ('train', 529),
#  'DME-6884821-44': ('train', 530),
#  'NORMAL-4999322-48': ('train', 531),
#  'NORMAL-7748406-26': ('train', 532),
#  'DME-5607266-9': ('train', 533),
#  'DME-258763-11': ('train', 534),
#  'NORMAL-7154571-30': ('train', 535),
#  'NORMAL-9169269-21': ('train', 536),
#  'NORMAL-1989796-2': ('train', 537),
#  'NORMAL-7438443-1': ('train', 538),
#  'DME-4430279-9': ('train', 539),
#  'DME-6716735-10': ('train', 540),
#  'NORMAL-3724972-3': ('train', 541),
#  'DME-682285-5': ('train', 542),
#  'CNV-6652117-349': ('train', 543),
#  'DME-1591159-78': ('train', 544),
#  'CNV-6569286-1': ('train', 545),
#  'CNV-3537912-22': ('train', 546),
#  'DRUSEN-464044-14': ('train', 547),
#  'NORMAL-6664394-8': ('train', 548),
#  'NORMAL-2213497-3': ('train', 549),
#  'CNV-2515109-20': ('train', 550),
#  'DME-7990001-8': ('train', 551),
#  'NORMAL-3033985-9': ('train', 552),
#  'NORMAL-6503402-2': ('train', 553),
#  'CNV-7710023-65': ('train', 554),
#  'NORMAL-5323137-3': ('train', 555),
#  'DME-8602716-93': ('train', 556),
#  'DME-3757443-30': ('train', 557),
#  'NORMAL-4969102-11': ('train', 558),
#  'CNV-9598696-140': ('train', 559),
#  'DRUSEN-7685407-5': ('train', 560),
#  'CNV-6569286-125': ('train', 561),
#  'CNV-3514723-66': ('train', 562),
#  'CNV-8748941-45': ('train', 563),
#  'NORMAL-4310826-2': ('train', 564),
#  'CNV-6666538-302': ('train', 565),
#  'CNV-1997439-101': ('train', 566),
#  'CNV-1188386-604': ('train', 567),
#  'CNV-451136-82': ('train', 568),
#  'NORMAL-4047469-6': ('train', 569),
#  'CNV-794538-23': ('train', 570),
#  'NORMAL-568518-15': ('train', 571),
#  'DRUSEN-463772-1': ('train', 572),
#  'CNV-4176900-17': ('train', 573),
#  'CNV-5697282-3': ('train', 574),
#  'NORMAL-3833528-7': ('train', 575),
#  'DME-4969104-12': ('train', 576),
#  'NORMAL-7428531-2': ('train', 577),
#  'NORMAL-2373878-3': ('train', 578),
#  'CNV-1112835-100': ('train', 579),
#  'CNV-904464-147': ('train', 580),
#  'NORMAL-2911008-12': ('train', 581),
#  'CNV-364469-56': ('train', 582),
#  'NORMAL-1077513-11': ('train', 583),
#  'NORMAL-7602231-24': ('train', 584),
#  'NORMAL-8497632-5': ('train', 585),
#  'DME-5083664-1': ('train', 586),
#  'CNV-4314136-5': ('train', 587),
#  'CNV-4731481-2': ('train', 588),
#  'CNV-6001487-8': ('train', 589),
#  'NORMAL-4527789-8': ('train', 590),
#  'NORMAL-4384544-13': ('train', 591),
#  'NORMAL-190271-7': ('train', 592),
#  'NORMAL-7639181-6': ('train', 593),
#  'CNV-4020729-100': ('train', 594),
#  'CNV-6116901-24': ('train', 595),
#  'CNV-6947782-74': ('train', 596),
#  'CNV-1632795-56': ('train', 597),
#  'NORMAL-3905909-26': ('train', 598),
#  'NORMAL-5359684-3': ('train', 599),
#  'CNV-6783162-19': ('train', 600),
#  'CNV-178673-10': ('train', 601),
#  'NORMAL-8954210-17': ('train', 602),
#  'NORMAL-869397-11': ('train', 603),
#  'NORMAL-6328436-13': ('train', 604),
#  'CNV-6566667-10': ('train', 605),
#  'DRUSEN-9072701-42': ('train', 606),
#  'NORMAL-1027133-4': ('train', 607),
#  'DME-4643364-23': ('train', 608),
#  'NORMAL-3248437-27': ('train', 609),
#  'CNV-1963682-5': ('train', 610),
#  'CNV-451136-280': ('train', 611),
#  'NORMAL-4987303-2': ('train', 612),
#  'NORMAL-3068234-14': ('train', 613),
#  'NORMAL-6371266-13': ('train', 614),
#  'NORMAL-6508224-20': ('train', 615),
#  'CNV-1641792-42': ('train', 616),
#  'DRUSEN-8023853-132': ('train', 617),
#  'CNV-7585537-35': ('train', 618),
#  'CNV-6369482-11': ('train', 619),
#  'DME-7950284-6': ('train', 620),
#  'NORMAL-5785398-4': ('train', 621),
#  'NORMAL-6405083-18': ('train', 622),
#  'NORMAL-7792808-18': ('train', 623),
#  'CNV-5429703-43': ('train', 624),
#  'CNV-1290410-1': ('train', 625),
#  'NORMAL-6325987-5': ('train', 626),
#  'CNV-6717547-7': ('train', 627),
#  'CNV-5969175-53': ('train', 628),
#  'DRUSEN-5811898-54': ('train', 629),
#  'CNV-1169820-85': ('train', 630),
#  'NORMAL-7988812-8': ('train', 631),
#  'CNV-7487279-46': ('train', 632),
#  'CNV-7555604-10': ('train', 633),
#  'DME-8889771-81': ('train', 634),
#  'DRUSEN-8023853-126': ('train', 635),
#  'DME-9508635-4': ('train', 636),
#  'DME-633268-64': ('train', 637),
#  'NORMAL-9202950-26': ('train', 638),
#  'NORMAL-3756907-12': ('train', 639),
#  'CNV-4107394-73': ('train', 640),
#  'CNV-538779-42': ('train', 641),
#  'NORMAL-9850252-11': ('train', 642),
#  'NORMAL-2029828-4': ('train', 643),
#  'NORMAL-7793610-14': ('train', 644),
#  'NORMAL-4412751-6': ('train', 645),
#  'NORMAL-3507119-22': ('train', 646),
#  'CNV-9547888-19': ('train', 647),
#  'DME-4242335-176': ('train', 648),
#  'CNV-4370501-14': ('train', 649),
#  'CNV-2192440-90': ('train', 650),
#  'NORMAL-7521991-5': ('train', 651),
#  'DME-4630435-6': ('train', 652),
#  'CNV-9935363-68': ('train', 653),
#  'CNV-995513-87': ('train', 654),
#  'CNV-6566667-123': ('train', 655),
#  'CNV-163081-146': ('train', 656),
#  'NORMAL-3093614-3': ('train', 657),
#  'CNV-4020729-59': ('train', 658),
#  'CNV-172472-257': ('train', 659),
#  'CNV-1112835-296': ('train', 660),
#  'NORMAL-5592767-5': ('train', 661),
#  'CNV-8087608-5': ('train', 662),
#  'NORMAL-2401089-18': ('train', 663),
#  'NORMAL-1428906-8': ('train', 664),
#  'NORMAL-9492371-9': ('train', 665),
#  'CNV-9642959-57': ('train', 666),
#  'NORMAL-3811618-30': ('train', 667),
#  'NORMAL-7016158-5': ('train', 668),
#  'NORMAL-8975291-4': ('train', 669),
#  'NORMAL-1888479-4': ('train', 670),
#  'NORMAL-1198686-12': ('train', 671),
#  'CNV-1260317-97': ('train', 672),
#  'NORMAL-6606865-5': ('train', 673),
#  'CNV-904464-183': ('train', 674),
#  'NORMAL-4445075-14': ('train', 675),
#  'NORMAL-3534474-6': ('train', 676),
#  'NORMAL-3596129-2': ('train', 677),
#  'NORMAL-2937821-8': ('train', 678),
#  'CNV-5434564-6': ('train', 679),
#  'NORMAL-5803849-4': ('train', 680),
#  'CNV-154835-70': ('train', 681),
#  'NORMAL-3356207-4': ('train', 682),
#  'NORMAL-6990363-5': ('train', 683),
#  'NORMAL-1571596-4': ('train', 684),
#  'CNV-3818682-36': ('train', 685),
#  'NORMAL-3816498-12': ('train', 686),
#  'DME-7578162-48': ('train', 687),
#  'NORMAL-1543956-14': ('train', 688),
#  'DME-4376118-3': ('train', 689),
#  'NORMAL-4462555-10': ('train', 690),
#  'NORMAL-3230369-2': ('train', 691),
#  'NORMAL-3958937-8': ('train', 692),
#  'NORMAL-2460548-1': ('train', 693),
#  'DRUSEN-8039905-4': ('train', 694),
#  'NORMAL-6256619-6': ('train', 695),
#  'NORMAL-9251-16': ('train', 696),
#  'CNV-9374492-365': ('train', 697),
#  'NORMAL-6191214-1': ('train', 698),
#  'CNV-6652117-100': ('train', 699),
#  'CNV-3618489-54': ('train', 700),
#  'NORMAL-4389726-7': ('train', 701),
#  'NORMAL-7602231-22': ('train', 702),
#  'NORMAL-9660862-7': ('train', 703),
#  'NORMAL-549356-3': ('train', 704),
#  'CNV-4643364-79': ('train', 705),
#  'NORMAL-6649351-4': ('train', 706),
#  'NORMAL-1714859-8': ('train', 707),
#  'NORMAL-2371458-23': ('train', 708),
#  'CNV-4412124-24': ('train', 709),
#  'NORMAL-3075392-13': ('train', 710),
#  'DRUSEN-2257047-44': ('train', 711),
#  'CNV-9374492-172': ('train', 712),
#  'CNV-6566667-71': ('train', 713),
#  'DME-5086150-27': ('train', 714),
#  'NORMAL-9660986-9': ('train', 715),
#  'CNV-4973751-20': ('train', 716),
#  'DME-958637-3': ('train', 717),
#  'NORMAL-5544453-4': ('train', 718),
#  'CNV-7694510-24': ('train', 719),
#  'NORMAL-8941787-3': ('train', 720),
#  'CNV-6369482-12': ('train', 721),
#  'CNV-1131664-48': ('train', 722),
#  'NORMAL-1219253-28': ('train', 723),
#  'NORMAL-1293282-13': ('train', 724),
#  'NORMAL-3928260-7': ('train', 725),
#  'NORMAL-7972888-11': ('train', 726),
#  'NORMAL-6436428-1': ('train', 727),
#  'NORMAL-5605451-1': ('train', 728),
#  'NORMAL-8936902-8': ('train', 729),
#  'CNV-2198788-5': ('train', 730),
#  'NORMAL-9627194-8': ('train', 731),
#  'DRUSEN-1789270-25': ('train', 732),
#  'CNV-4907724-31': ('train', 733),
#  'NORMAL-9152820-13': ('train', 734),
#  'CNV-4952759-97': ('train', 735),
#  'NORMAL-6707435-7': ('train', 736),
#  'CNV-697731-30': ('train', 737),
#  'NORMAL-2732586-7': ('train', 738),
#  'NORMAL-8371885-8': ('train', 739),
#  'CNV-4670940-3': ('train', 740),
#  'CNV-6947782-26': ('train', 741),
#  'DME-5006393-46': ('train', 742),
#  'DRUSEN-8023853-142': ('train', 743),
#  'NORMAL-4023248-3': ('train', 744),
#  'DME-1875232-5': ('train', 745),
#  'NORMAL-486271-8': ('train', 746),
#  'DME-5580182-2': ('train', 747),
#  'NORMAL-6010160-3': ('train', 748),
#  'NORMAL-8838274-4': ('train', 749),
#  'DME-4630435-7': ('train', 750),
#  'NORMAL-3380901-7': ('train', 751),
#  'NORMAL-7694510-16': ('train', 752),
#  'DRUSEN-3424668-22': ('train', 753),
#  'CNV-6581164-166': ('train', 754),
#  'NORMAL-3644026-30': ('train', 755),
#  'NORMAL-7026057-7': ('train', 756),
#  'CNV-9206635-74': ('train', 757),
#  'DRUSEN-4450592-2': ('train', 758),
#  'NORMAL-3153386-10': ('train', 759),
#  'NORMAL-9257376-7': ('train', 760),
#  'CNV-8728968-157': ('train', 761),
#  'CNV-7487279-9': ('train', 762),
#  'CNV-457527-15': ('train', 763),
#  'NORMAL-5902587-8': ('train', 764),
#  'CNV-732516-256': ('train', 765),
#  'NORMAL-7839442-5': ('train', 766),
#  'CNV-8819395-74': ('train', 767),
#  'CNV-6569286-27': ('train', 768),
#  'CNV-9642260-232': ('train', 769),
#  'NORMAL-9905701-8': ('train', 770),
#  'CNV-3616460-39': ('train', 771),
#  'NORMAL-8409287-1': ('train', 772),
#  'NORMAL-8027454-27': ('train', 773),
#  'CNV-904464-198': ('train', 774),
#  'DME-5549735-10': ('train', 775),
#  'NORMAL-5763760-14': ('train', 776),
#  'DRUSEN-1225603-44': ('train', 777),
#  'NORMAL-1235052-1': ('train', 778),
#  'CNV-908456-23': ('train', 779),
#  'CNV-1188386-10': ('train', 780),
#  'CNV-7531689-44': ('train', 781),
#  'CNV-4191828-2': ('train', 782),
#  'NORMAL-8600957-20': ('train', 783),
#  'NORMAL-1935298-3': ('train', 784),
#  'CNV-163081-92': ('train', 785),
#  'CNV-9884539-21': ('train', 786),
#  'CNV-375851-71': ('train', 787),
#  'NORMAL-6422023-1': ('train', 788),
#  'CNV-2177326-7': ('train', 789),
#  'DME-4336607-55': ('train', 790),
#  'CNV-933576-118': ('train', 791),
#  'CNV-5557306-27': ('train', 792),
#  'NORMAL-6371266-11': ('train', 793),
#  'NORMAL-4778166-20': ('train', 794),
#  'CNV-9911627-47': ('train', 795),
#  'DME-9510741-2': ('train', 796),
#  'CNV-1699976-231': ('train', 797),
#  'NORMAL-9063349-6': ('train', 798),
#  'CNV-2116022-6': ('train', 799),
#  'DME-9853060-19': ('train', 800),
#  'CNV-1699976-370': ('train', 801),
#  'DME-1695472-23': ('train', 802),
#  'NORMAL-6002699-4': ('train', 803),
#  'CNV-6569286-7': ('train', 804),
#  'CNV-9734808-70': ('train', 805),
#  'NORMAL-7772609-27': ('train', 806),
#  'CNV-8783825-1': ('train', 807),
#  'DME-4336607-21': ('train', 808),
#  'DRUSEN-6190971-22': ('train', 809),
#  'CNV-1986974-6': ('train', 810),
#  'DME-8560276-1': ('train', 811),
#  'CNV-7393104-31': ('train', 812),
#  'NORMAL-7050782-5': ('train', 813),
#  'NORMAL-3674923-6': ('train', 814),
#  'NORMAL-7839442-1': ('train', 815),
#  'NORMAL-9699329-21': ('train', 816),
#  'DRUSEN-8351260-6': ('train', 817),
#  'DRUSEN-9894035-29': ('train', 818),
#  'DRUSEN-7973089-11': ('train', 819),
#  'CNV-2784437-2': ('train', 820),
#  'CNV-776149-10': ('train', 821),
#  'CNV-3791742-4': ('train', 822),
#  'NORMAL-3747803-6': ('train', 823),
#  'NORMAL-8555080-26': ('train', 824),
#  'CNV-1702663-31': ('train', 825),
#  'NORMAL-7065460-54': ('train', 826),
#  'NORMAL-4577637-19': ('train', 827),
#  'NORMAL-5821915-16': ('train', 828),
#  'CNV-7159021-36': ('train', 829),
#  'NORMAL-6527133-2': ('train', 830),
#  'DRUSEN-3086272-5': ('train', 831),
#  'NORMAL-9125879-5': ('train', 832),
#  'DME-3358004-22': ('train', 833),
#  'NORMAL-7426633-8': ('train', 834),
#  'NORMAL-4668788-2': ('train', 835),
#  'NORMAL-9758159-2': ('train', 836),
#  'NORMAL-5744466-9': ('train', 837),
#  'CNV-3453634-23': ('train', 838),
#  'NORMAL-5944037-8': ('train', 839),
#  'NORMAL-8999827-15': ('train', 840),
#  'CNV-7315522-266': ('train', 841),
#  'CNV-9997417-7': ('train', 842),
#  'CNV-1188386-73': ('train', 843),
#  'CNV-933576-128': ('train', 844),
#  'NORMAL-9794933-17': ('train', 845),
#  'CNV-8014630-37': ('train', 846),
#  'NORMAL-4330656-5': ('train', 847),
#  'CNV-5434564-17': ('train', 848),
#  'CNV-6741522-163': ('train', 849),
#  'NORMAL-4354710-1': ('train', 850),
#  'CNV-1641792-76': ('train', 851),
#  'NORMAL-9474513-19': ('train', 852),
#  'DRUSEN-228939-2': ('train', 853),
#  'DRUSEN-5434336-44': ('train', 854),
#  'CNV-1188386-11': ('train', 855),
#  'CNV-7393104-47': ('train', 856),
#  'NORMAL-2550236-7': ('train', 857),
#  'CNV-6668596-160': ('train', 858),
#  'CNV-5823679-62': ('train', 859),
#  'DRUSEN-783692-1': ('train', 860),
#  'CNV-9642959-73': ('train', 861),
#  'NORMAL-2287992-9': ('train', 862),
#  'CNV-4219137-48': ('train', 863),
#  'NORMAL-3382680-3': ('train', 864),
#  'CNV-154835-1': ('train', 865),
#  'NORMAL-9045771-3': ('train', 866),
#  'NORMAL-6598291-10': ('train', 867),
#  'CNV-4952759-84': ('train', 868),
#  'DRUSEN-1651625-12': ('train', 869),
#  'CNV-2655276-60': ('train', 870),
#  'DME-30521-68': ('train', 871),
#  'DME-7763916-110': ('train', 872),
#  'CNV-1997439-181': ('train', 873),
#  'CNV-4910354-7': ('train', 874),
#  'NORMAL-7939555-3': ('train', 875),
#  'NORMAL-7304913-9': ('train', 876),
#  'NORMAL-1842556-6': ('train', 877),
#  'CNV-1786810-11': ('train', 878),
#  'CNV-5603164-47': ('train', 879),
#  'DRUSEN-8986660-71': ('train', 880),
#  'CNV-904464-84': ('train', 881),
#  'CNV-6947782-20': ('train', 882),
#  'NORMAL-5103899-43': ('train', 883),
#  'DME-306172-60': ('train', 884),
#  'NORMAL-6368170-3': ('train', 885),
#  'NORMAL-4478609-1': ('train', 886),
#  'NORMAL-3674955-3': ('train', 887),
#  'NORMAL-8647070-7': ('train', 888),
#  'CNV-4521812-18': ('train', 889),
#  'CNV-3163547-46': ('train', 890),
#  'CNV-7852568-39': ('train', 891),
#  'NORMAL-9026878-15': ('train', 892),
#  'NORMAL-4299338-7': ('train', 893),
#  'DME-1608084-7': ('train', 894),
#  'NORMAL-1124422-8': ('train', 895),
#  'NORMAL-3847910-20': ('train', 896),
#  'CNV-7710023-12': ('train', 897),
#  'NORMAL-1302346-8': ('train', 898),
#  'NORMAL-198660-6': ('train', 899),
#  'NORMAL-1600980-9': ('train', 900),
#  'NORMAL-5030676-19': ('train', 901),
#  'NORMAL-7159742-30': ('train', 902),
#  'NORMAL-3847910-5': ('train', 903),
#  'NORMAL-4556266-16': ('train', 904),
#  'NORMAL-6624615-6': ('train', 905),
#  'CNV-3715091-122': ('train', 906),
#  'CNV-4524167-8': ('train', 907),
#  'DME-1726544-11': ('train', 908),
#  'NORMAL-4001769-26': ('train', 909),
#  'DRUSEN-5710007-29': ('train', 910),
#  'DME-8602716-10': ('train', 911),
#  'NORMAL-7138480-8': ('train', 912),
#  'NORMAL-4213340-8': ('train', 913),
#  'NORMAL-3077276-2': ('train', 914),
#  'DRUSEN-2444883-16': ('train', 915),
#  'CNV-3715091-184': ('train', 916),
#  'NORMAL-3609102-23': ('train', 917),
#  'CNV-5409617-34': ('train', 918),
#  'NORMAL-7938317-6': ('train', 919),
#  'NORMAL-9874675-13': ('train', 920),
#  'DME-3483651-5': ('train', 921),
#  'NORMAL-9574134-10': ('train', 922),
#  'CNV-1174703-18': ('train', 923),
#  'DME-3157783-87': ('train', 924),
#  'CNV-6493580-151': ('train', 925),
#  'DME-4789534-2': ('train', 926),
#  'CNV-6652117-143': ('train', 927),
#  'DRUSEN-9861332-4': ('train', 928),
#  'NORMAL-3592502-4': ('train', 929),
#  'NORMAL-4004086-16': ('train', 930),
#  'CNV-3318854-271': ('train', 931),
#  'DRUSEN-1077513-16': ('train', 932),
#  'NORMAL-9294492-4': ('train', 933),
#  'DRUSEN-8086850-120': ('train', 934),
#  'NORMAL-6521414-5': ('train', 935),
#  'CNV-6581164-226': ('train', 936),
#  'DME-9997680-14': ('train', 937),
#  'NORMAL-5587871-4': ('train', 938),
#  'CNV-451136-270': ('train', 939),
#  'CNV-5674369-158': ('train', 940),
#  'CNV-3715091-31': ('train', 941),
#  'DME-4244491-23': ('train', 942),
#  'NORMAL-4600375-10': ('train', 943),
#  'DME-8861620-2': ('train', 944),
#  'NORMAL-8876424-23': ('train', 945),
#  'NORMAL-3248437-11': ('train', 946),
#  'DRUSEN-8549730-9': ('train', 947),
#  'CNV-9642959-96': ('train', 948),
#  'NORMAL-7591008-47': ('train', 949),
#  'CNV-9320911-267': ('train', 950),
#  'NORMAL-7434394-2': ('train', 951),
#  'CNV-9547888-20': ('train', 952),
#  'NORMAL-3380901-6': ('train', 953),
#  'CNV-5851527-5': ('train', 954),
#  'CNV-6947782-78': ('train', 955),
#  'CNV-3318854-76': ('train', 956),
#  'CNV-1279887-90': ('train', 957),
#  'NORMAL-3075392-2': ('train', 958),
#  'NORMAL-716041-4': ('train', 959),
#  'NORMAL-3673740-9': ('train', 960),
#  'NORMAL-5980554-7': ('train', 961),
#  'CNV-8715526-16': ('train', 962),
#  'NORMAL-6662205-6': ('train', 963),
#  'DME-8525575-103': ('train', 964),
#  'NORMAL-3837024-2': ('train', 965),
#  'NORMAL-8498304-7': ('train', 966),
#  'NORMAL-5171640-8': ('train', 967),
#  'NORMAL-7189446-14': ('train', 968),
#  'NORMAL-1847888-11': ('train', 969),
#  'NORMAL-9267111-51': ('train', 970),
#  'NORMAL-1016042-56': ('train', 971),
#  'CNV-3541867-18': ('train', 972),
#  'CNV-3453634-94': ('train', 973),
#  'CNV-1651625-8': ('train', 974),
#  'NORMAL-7022812-14': ('train', 975),
#  'CNV-4731481-10': ('train', 976),
#  'NORMAL-9961073-12': ('train', 977),
#  'NORMAL-1235052-5': ('train', 978),
#  'CNV-4412124-33': ('train', 979),
#  'NORMAL-6972746-28': ('train', 980),
#  'CNV-8783825-255': ('train', 981),
#  'CNV-172472-381': ('train', 982),
#  'CNV-172472-60': ('train', 983),
#  'NORMAL-5025855-6': ('train', 984),
#  'NORMAL-9264570-11': ('train', 985),
#  'NORMAL-3574786-8': ('train', 986),
#  'CNV-3248882-19': ('train', 987),
#  'NORMAL-6002699-2': ('train', 988),
#  'CNV-538779-58': ('train', 989),
#  'CNV-1279887-122': ('train', 990),
#  'CNV-1188386-573': ('train', 991),
#  'CNV-908456-9': ('train', 992),
#  'CNV-2541184-6': ('train', 993),
#  'CNV-6369482-100': ('train', 994),
#  'NORMAL-2677505-7': ('train', 995),
#  'NORMAL-3740938-15': ('train', 996),
#  'CNV-732516-138': ('train', 997),
#  'NORMAL-7319607-32': ('train', 998),
#  'CNV-779442-236': ('train', 999),
#  ...}

# %%
len(info_of_image)
# Out:
# 109309

# %%
from tqdm import tqdm
import concurrent.futures
from PIL import Image
import random

# %%
with tqdm(desc="Processing", total=len(split_info), unit="pic") as pbar:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = set()
    
        def preprocess(_fp, _info):
            try:
                _split, _index = _info
        
                with Image.open(_fp) as im:
                    if im.mode != "L":
                        im = im.convert("L")
                    im = im.resize((SIZE, SIZE), Image.BICUBIC)
        
                    images_of_split[_split][_index] = np.asarray(im)
            except Exception as e:
                print(e)
                raise e
    
        for child in SOURCE.rglob("*"):
            if child.is_file():
                try:
                    info = info_of_image.pop(child.stem)
                except KeyError:
                    pbar.write(f"Skipping {child.name}")
                    continue
                future = executor.submit(preprocess, child, info)
                future.add_done_callback(lambda _: pbar.update())
                futures.add(future)
        
        missing_ims = list(info_of_image.keys())
        
        if not len(missing_ims) == 0:
            pbar.write(f"The dataset at {SOURCE} is incomplete.")
            if len(missing_ims) == 1:
                pbar.write(f"Missing image with id {missing_ims[0]}")
            elif 1 < len(info_of_image) < 6:
                im_ids_str = ", ".join(missing_ims[:-1]) + f", and {missing_ims[-1]}"
                pbar.write(f"Missing files with ids {im_ids_str}")
            else:
                random_im_ids = random.sample(missing_ims, 5)
                im_ids_str = ", ".join(random_im_ids[:-1]) + f", and {random_im_ids[-1]}"
                pbar.write(f"Missing {len(missing_ims)} images such as {im_ids_str}")
            sys.exit(1)
    
        concurrent.futures.wait(futures)
# Out:
# Processing: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 109309/109309 [03:09<00:00, 577.09pic/s]

# %%
exceptions = set()

for future in futures:
    exception = future.exception()
    if exception:
        exceptions.add(exception)

for exception in exceptions:
    print(exception)

# %%
mnist = np.load("/root/.medmnist/octmnist.npz")
labels_of_split = {SPLIT: mnist[f"{SPLIT}_labels"] for SPLIT in SPLITS}

name_to_array = {}
for data_name, data_of_split in [("images", images_of_split), ("labels", labels_of_split)]:
    for SPLIT in SPLITS:
        name_to_array[f"{SPLIT}_{data_name}"] = data_of_split[SPLIT]

np.savez_compressed("/root/test.npz", **name_to_array)
